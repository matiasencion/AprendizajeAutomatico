# %%
import pandas as pd

df = pd.read_csv("../dataset/futbol_uruguayo.csv")

df["date"] = pd.to_datetime(df["date"])

print(df.head())
# Out:
#                    home                              away       date   gh  \
# 0           Bella Vista                 Defensor Sporting 1932-03-05  1.0
# 1            CA Penarol                       River Plate 1932-03-05  1.0
# 2  Montevideo Wanderers                       Racing Club 1932-03-05  3.0
# 3       Central Espanol        Rampla Juniors Futbol Club 1932-03-05  1.0
# 4              Nacional  Institucion Atletica Sud America 1932-03-05  2.0
#
#     ga full_time competition                      home_ident  \
# 0  2.0         F     uruguay           Bella Vista (Uruguay)
# 1  1.0         F     uruguay            CA Penarol (Uruguay)
# 2  0.0         F     uruguay  Montevideo Wanderers (Uruguay)
# 3  0.0         F     uruguay       Central Espanol (Uruguay)
# 4  0.0         F     uruguay              Nacional (Uruguay)
#
#                                    away_ident home_country away_country  \
# 0                 Defensor Sporting (Uruguay)      uruguay      uruguay
# 1                       River Plate (Uruguay)      uruguay      uruguay
# 2                       Racing Club (Uruguay)      uruguay      uruguay
# 3        Rampla Juniors Futbol Club (Uruguay)      uruguay      uruguay
# 4  Institucion Atletica Sud America (Uruguay)      uruguay      uruguay
#
#   home_code away_code home_continent away_continent      continent     level
# 0        UY        UY  South America  South America  South America  national
# 1        UY        UY  South America  South America  South America  national
# 2        UY        UY  South America  South America  South America  national
# 3        UY        UY  South America  South America  South America  national
# 4        UY        UY  South America  South America  South America  national

# %%
import sys
import os

# Agrega la carpeta padre (Tarea1) al path de búsqueda de Python
sys.path.append(os.path.abspath(".."))

from baseClassifier.base_classifier import base_classifier

row = df.iloc[3000]
result = base_classifier(df, 10, row)
print(result)
# Out:
# L
